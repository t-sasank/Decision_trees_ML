# %% [markdown]
# #Enjoy Sport Decision Tree with Scikit Learn

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import graphviz

# %%
data = pd.read_csv('EnjoySport.csv')

# %% [markdown]
# ##Label Encoding

# %%
# Creating a label encoder to convert text to numbers
le = LabelEncoder()
data['outlook'] = le.fit_transform(data['outlook'])
data['temp'] = le.fit_transform(data['temp'])
data['humid'] = le.fit_transform(data['humid'])
data['windy'] = le.fit_transform(data['windy'])
data['play']  = le.fit_transform(data['play'])

# Splitting the data into features and target variable
X = data[['outlook', 'temp', 'humid', 'windy']]
y = data['play']

# %% [markdown]
# ##Model Building

# %%
tree = DecisionTreeClassifier(criterion='entropy',random_state=0)
tree.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
dot_data = export_graphviz(clf, out_file=None)
graph = graphviz.Source(dot_data)
graph.render("iris")

# Export the decision tree with more options
dot_data = export_graphviz(tree, out_file=None,
                           feature_names=['outlook', 'temp', 'windy', 'humid'],
                           class_names=['no', 'yes'],
                           filled=True, rounded=True,
                           special_characters=True)


# Create a graphviz Source object
graph = graphviz.Source(dot_data)

# Render the graph
graph
